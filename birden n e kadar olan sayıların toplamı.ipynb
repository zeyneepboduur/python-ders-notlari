# %%
while True:
    try:
     n = int(input("lütfen pozitif bir tam sayı giriniz:"))
     if n>0:
        break
     else:
        print("lütfen pozitif bir tam sayı giriniz.")
    except:
        print("HATA")
toplam = 0
for i in range(1, n+1):
    toplam += i
    print("1'den", n, "kadar olan sayıların toplamı:", toplam)
# Out:
# 1'den 5 kadar olan sayıların toplamı: 1
# 1'den 5 kadar olan sayıların toplamı: 3
# 1'den 5 kadar olan sayıların toplamı: 6
# 1'den 5 kadar olan sayıların toplamı: 10
# 1'den 5 kadar olan sayıların toplamı: 15
